# %%
# El módulo turtleworld está en la carpeta de arriba (''..'')
import sys
sys.path.append('..')

# %%
# Para que Jupyter recarge los módulos si han cambiado
# %load_ext autoreload
# %autoreload 2

# %%
import turtleworld as tw

# %% [markdown]
# ## Pruebas de la clase `TortugaSencilla`

# %%
t = tw.TortugaSencilla()
t.print_info()
# Out:
# Tortuga 'Dora
#   Posición   : [0 0]
#   Orientación: [0 1]

# %%
t = tw.TortugaSencilla()
pi = tw.pi
def cuadrado(tortuga, lado):
    for i in range(4):
        tortuga.avanza(1)
        tortuga.gira(-pi/2)
    tortuga.plot()
cuadrado(t, 1)
t.reinicia()

# %%
t.reinicia()
t.plot()

# %% [markdown]
# ## Pruebas de la clase `TortugaConIcono`

# %%
import turtleworld as tw
t2 = tw.TortugaConIcono()
t2.print_info()
# Out:
# Tortuga 'Dora
#   Posición   : [0 0]
#   Orientación: [0 1]
# Icono de la tortuga:

# %%
import matplotlib.pylab as plt
t2 = tw.TortugaConIcono()
import time
for i in range(5):
    t2.avanza(1)
    t2.gira(2*pi/5)
    t2.plot()
    time.sleep(1)
#    t2.limpia_grafica()
#    plt.show()

# %% [markdown]
# ## Tortugas animadas :)
# https://towardsdatascience.com/matplotlib-animations-in-jupyter-notebook-4422e4f0e389

# %%
# Enable interactive plot
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

t3 = tw.TortugaSencilla()
fig, ax = plt.subplots()

line, = ax.plot([])

x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)
plt.plot(x, y)
plt.show()

ax.set_xlim(0, 2*np.pi)
ax.set_ylim(-1.1, 1.1)

def animate(frame_num):
    y = np.sin(x + 2*np.pi * frame_num/100)
    line.set_data((x, y))
    return line

def animate_tor(frame_num):
    t3.avanza(1)
    t3.gira(pi/2)
    listax = [P[0] for P in t3.ruta]
    listay = [P[1] for P in t3.ruta]
    line.set_data((listax, listay))
    return line

anim = FuncAnimation(fig, animate, frames=100, interval=20)
plt.show()
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/usr/lib/python3/dist-packages/matplotlib/animation.py", line 1465, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="700">
# <img src="data:image/png;base64,..." width="640">

# %%
# Enable interactive plot
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation

t3 = tw.TortugaSencilla()

line, = t3.ax.plot([])

def animate_tortu(frame_num):
    t3.avanza(1)
    t3.gira(pi/2)
    listax = [P[0] for P in t3.ruta]
    listay = [P[1] for P in t3.ruta]
    line.set_data((listax, listay))
    time.sleep(0.5)
    return line

anim = FuncAnimation(t3.fig, animate_tortu, frames=100, interval=20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
